# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import BernoulliNB
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.feature_extraction import _stop_words
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay, classification_report

import nltk
import re

# %% [markdown]
# <div style="background:#FFFFE0;padding:20px;color:#000000;margin-top:10px;">
# Scope: Este dato se extrae de Elkins, Ginsburg y Melton, The Endurance of National Constitutions (Cambridge University Press, 2009). Mide el porcentaje de 701 temas principales de la encuesta del PCCh incluidos en una constitución dada.
#
# Length (en palabras): Este es simplemente un informe del número total de palabras de la Constitución, medido por Microsoft Word.
#
# Executive Power: Este es un índice aditivo extraído del documento de trabajo "Restricciones Constitucionales a la Legislación Ejecutiva". El índice oscila entre 0 y 7 y refleja la presencia o ausencia de siete aspectos importantes de la legislación ejecutiva:
#
# (1) la facultad de iniciar leyes;
#
# (2) la facultad de emitir decretos;
#
# (3) la facultad de iniciar reformas constitucionales;
#
# (4) la facultad de declarar estados de emergencia;
#
# (5) el poder de veto;
#
# (6) la facultad de impugnar la constitucionalidad de la legislación;
#
# (7) la facultad de disolver la legislatura.
#
# El puntaje del índice indica el número total de estos poderes otorgados a cualquier ejecutivo nacional (presidente, primer ministro o asignado al gobierno) en su conjunto.
#
# Legislative Power: Captura el grado formal de poder que la Constitución asigna a la legislatura. El indicador se extrae de Elkins, Ginsburg y Melton, The Endurance of National Constitutions (Cambridge University Press, 2009), donde creamos un conjunto de variables binarias del PCC para que coincidan con la encuesta de 32 ítems desarrollada por M. Steven Fish y Mathew Kroenig en The Handbook of National Legislatures: A Global Survey (Cambridge University Press, 2009). La puntuación del índice es simplemente la media de los 32 elementos binarios, donde los números más altos indican mayor poder legislativo y los números más bajos, menor.
#
# Judicial Independence: Este índice se extrae del artículo de Ginsburg y Melton, "¿Importa realmente la independencia judicial de jure? Una reevaluación de las explicaciones sobre la independencia judicial". Se trata de un índice aditivo que va de 0 a 6 y que captura la presencia o ausencia constitucional de seis características que se cree que mejoran la independencia judicial.
# Estas seis características son:
# (1) si la constitución contiene una declaración explícita de independencia judicial;
# (2) si la constitución establece que los jueces tienen nombramientos vitalicios;
# (3) si los nombramientos para el máximo tribunal implican a un consejo judicial o a dos (o más) actores;
# (4) si la destitución está prohibida o limitada de modo que requiere la propuesta de una mayoría cualificada en la legislatura, o si solo el público o el consejo judicial pueden proponer la destitución y se requiere la aprobación de otro actor político;
# (5) si la destitución se limita explícitamente a delitos y otras cuestiones de mala conducta, traición o violaciones de la constitución; y
# (6) si los salarios judiciales están protegidos contra reducciones.
#
# Number of Rights: En nuestro proyecto de libro sobre derechos humanos, analizamos un conjunto de 1172 derechos diferentes presentes en las constituciones nacionales. El índice de derechos indica la cantidad de estos derechos presentes en cada constitución.
#
# Preamble: Esto es algo que extraje de la propia plataforma. Contiene el texto del preámbulo de la Constitución de cada nación.
# </div>

# %%
# Descargamos recursos necesarios de nltk
#nltk.download('punkt')
#nltk.download('stopwords')

# %%
pd.set_option('display.max_rows', None)

# %%
df_const = pd.read_csv("Constitution Dataset.csv")
df_const
# Out:
#                     Country  Year Enacted  Scope Length (in Words)  \
# 0               Afghanistan          2004   0.67            10,227
# 1                   Albania          1998   0.61            13,826
# 2                   Algeria          1996   0.61            10,038
# 3                   Andorra          1993   0.51             8,740
# 4                    Angola          2010   0.80            27,181
# 5       Antigua and Barbuda          1981   0.56            38,464
# 6                 Argentina          1983   0.64            12,514
# 7                   Armenia          1995   0.66            13,786
# 8                 Australia          1901   0.43            17,318
# 9                   Austria          1945   0.57            41,366
# 10               Azerbaijan          1995   0.63            17,354
# 11                  Bahamas          1973   0.47            41,835
# 12                  Bahrain          2002   0.57            10,806
# 13               Bangladesh          1986   0.63            27,643
# 14                 Barbados          1966   0.40            34,144
# 15                  Belarus          1994   0.61            13,278
# 16                  Belgium          1831   0.59            16,119
# 17                   Belize          1981   0.47            39,629
# 18                    Benin          1990   0.56            11,386
# 19                   Bhutan          2008   0.64            13,632
# 20                  Bolivia          2009   0.74            39,375
# 21   Bosnia and Herzegovina          1995   0.41             5,454
# 22                 Botswana          1966   0.43            30,713
# 23                   Brazil          1988   0.70            64,488
# 24                   Brunei          1959   0.33            13,869
# 25                 Bulgaria          1991   0.70            13,641
# 26             Burkina Faso          1991   0.59            10,030
# 27                  Burundi          2005   0.66            17,574
# 28                 Cambodia          1993   0.61             8,936
# 29                 Cameroon          1972   0.46             8,444
# 30                   Canada          1867   0.40            19,565
# 31               Cape Verde          1980   0.76            32,132
# 32     Central African Rep.          2013   0.57             9,767
# 33                     Chad          1996   0.57            11,768
# 34                    Chile          1980   0.67            25,821
# 35                    China          1982   0.51            10,960
# 36                 Colombia          1991   0.76            46,902
# 37                  Comoros          2001   0.44             6,185
# 38                    Congo          2001   0.60             9,970
# 39         Congo, Dem. Rep.          2005   0.70            19,285
# 40               Costa Rica          1949   0.63            16,705
# 41            Cote d'Ivoire          2000   0.50             7,897
# 42                  Croatia          1991   0.59            10,898
# 43                     Cuba          1976   0.54            12,893
# 44                   Cyprus          1960   0.53            37,006
# 45           Czech Republic          1993   0.60            14,580
# 46                  Denmark          1953   0.53             6,221
# 47                 Djibouti          1992   0.41             6,666
# 48                 Dominica          1978   0.54            36,080
# 49       Dominican Republic          2010   0.70            29,710
# 50                  Ecuador          2008   0.79            54,555
# 51                    Egypt          2014   0.77            22,626
# 52              El Salvador          1983   0.64            22,823
# 53        Equatorial Guinea          1991   0.57             5,575
# 54                  Eritrea          1997   0.54             6,753
# 55                  Estonia          1992   0.59            11,344
# 56                 Ethiopia          1994   0.64            13,630
# 57                     Fiji          2013   0.63            40,773
# 58                  Finland          1999   0.61            12,640
# 59                   France          1958   0.50            10,180
# 60                    Gabon          1991   0.66            11,804
# 61                   Gambia          1996   0.73            43,465
# 62                  Georgia          1995   0.66            11,490
# 63                  Germany          1949   0.71            27,379
# 64                    Ghana          1992   0.71            53,985
# 65                   Greece          1975   0.73            26,989
# 66                  Grenada          1991   0.47            33,737
# 67                Guatemala          1985   0.60            28,692
# 68                   Guinea          2010   0.64            12,707
# 69            Guinea-Bissau          1984   0.57             7,820
# 70                   Guyana          1980   0.59            46,221
# 71                    Haiti          1987   0.69            18,488
# 72                 Honduras          1982   0.69            23,434
# 73                  Hungary          2011   0.69            15,247
# 74                  Iceland          1944   0.43             4,089
# 75                    India          1949   0.60           146,385
# 76                Indonesia          1959   0.56             5,915
# 77                     Iran          1979   0.66            16,179
# 78                     Iraq          2005   0.60            11,550
# 79                  Ireland          1937   0.56            16,007
# 80                   Israel          1958   0.39            17,053
# 81                    Italy          1947   0.67            11,708
# 82                  Jamaica          1962   0.40            38,048
# 83                    Japan          1946   0.36             4,998
# 84                   Jordan          1952   0.54            10,239
# 85               Kazakhstan          1995   0.56            13,482
# 86                    Kenya          2010   0.81            48,818
# 87                 Kiribati          1979   0.54            26,080
# 88                   Kosovo          2008   0.66            19,782
# 89                   Kuwait          1992   0.51             8,197
# 90               Kyrgyzstan          2010   0.71            14,327
# 91                     Laos          1991   0.46             4,820
# 92                   Latvia          1991   0.51             4,917
# 93                  Lebanon          1926   0.47             6,296
# 94                  Lesotho          1993   0.56            45,532
# 95                  Liberia          1986   0.59            11,667
# 96            Liechtenstein          1921   0.47             9,513
# 97                Lithuania          1992   0.66            12,214
# 98               Luxembourg          1868   0.53             5,601
# 99                Macedonia          1991   0.60            13,486
# 100              Madagascar          2010   0.60            15,759
# 101                  Malawi          1994   0.67            33,422
# 102                Malaysia          1957   0.59            64,080
# 103                Maldives          2008   0.61            23,991
# 104                    Mali          1992   0.54             7,503
# 105                   Malta          1964   0.47            31,820
# 106        Marshall Islands          1979   0.44            21,429
# 107              Mauritania          1991   0.49             6,997
# 108               Mauritius          1968   0.47            37,320
# 109                  Mexico          1917   0.76            57,087
# 110              Micronesia          1978   0.46             5,271
# 111                 Moldova          1994   0.61            12,818
# 112                  Monaco          1962   0.37             3,814
# 113                Mongolia          1992   0.56             8,250
# 114              Montenegro          2007   0.64            11,572
# 115                 Morocco          2011   0.64            15,897
# 116              Mozambique          2004   0.73            24,171
# 117                 Myanmar          2008   0.60            40,492
# 118                 Namibia          1990   0.59            24,198
# 119                   Nauru          1968   0.33            13,714
# 120                   Nepal          2006   0.70            32,753
# 121             Netherlands          1815   0.43             8,739
# 122             New Zealand          1852   0.21            48,438
# 123               Nicaragua          1987   0.64            20,535
# 124                   Niger          2010   0.66            14,806
# 125                 Nigeria          1999   0.63            66,263
# 126             North Korea          1972   0.50             7,364
# 127                  Norway          1814   0.51             7,307
# 128                    Oman          1996   0.56             7,233
# 129                Pakistan          2002   0.64            56,240
# 130                  Panama          1972   0.59            26,097
# 131        Papua New Guinea          1975   0.47            58,490
# 132                Paraguay          1992   0.61            25,461
# 133                    Peru          1993   0.70            19,216
# 134             Philippines          1987   0.71            21,954
# 135                  Poland          1997   0.66            19,602
# 136                Portugal          1976   0.76            35,219
# 137                   Qatar          2003   0.51             6,848
# 138                 Romania          1991   0.57            14,663
# 139                  Russia          1993   0.64            12,908
# 140                  Rwanda          2003   0.63            16,940
# 141   Saint Kitts and Nevis          1983   0.56            49,643
# 142             Saint Lucia          1978   0.61            38,271
# 143                   Samoa          1962   0.34            19,611
# 144   Sao Tome and Principe          1975   0.51             7,988
# 145            Saudi Arabia          1992   0.49             6,335
# 146                 Senegal          2001   0.53            10,866
# 147                  Serbia          2006   0.64            19,891
# 148              Seychelles          1993   0.63            39,729
# 149            Sierra Leone          1996   0.54            44,636
# 150               Singapore          1963   0.50            40,076
# 151         Slovak Republic          1992   0.67            18,402
# 152                Slovenia          1991   0.61            11,406
# 153         Solomon Islands          1978   0.41            31,836
# 154                 Somalia          2012   0.64            19,823
# 155            South Africa          1996   0.64            43,062
# 156             South Korea          1948   0.66             9,059
# 157             South Sudan          2011   0.73            27,191
# 158                   Spain          1978   0.63            17,608
# 159               Sri Lanka          1978   0.67            40,085
# 160                   Sudan          2005   0.71            26,644
# 161                Suriname          1987   0.57            12,488
# 162               Swaziland          2005   0.66            48,604
# 163                  Sweden          1974   0.61            13,635
# 164             Switzerland          1999   0.63            16,484
# 165                   Syria          2012   0.63             8,154
# 166                  Taiwan          1947   0.50            11,558
# 167              Tajikistan          1994   0.63             7,917
# 168                Tanzania          1977   0.59            35,651
# 169                Thailand          2014   0.59             7,683
# 170                   Timor          2002   0.64            15,307
# 171                    Togo          1992   0.57            10,252
# 172                   Tonga          1875   0.41            10,192
# 173     Trinidad and Tobago          1976   0.51            32,567
# 174                 Tunisia          2014   0.70             9,508
# 175                  Turkey          1982   0.69            29,727
# 176            Turkmenistan          2008   0.50             5,735
# 177                  Tuvalu          1986   0.40            34,801
# 178                  U.S.A.          1789   0.49             7,762
# 179                  Uganda          1995   0.69            49,448
# 180                 Ukraine          1996   0.66            19,299
# 181    United Arab Emirates          1971   0.47            11,557
# 182          United Kingdom          1215   0.43            54,408
# 183                 Uruguay          1985   0.66            29,911
# 184              Uzbekistan          1992   0.59             7,941
# 185                 Vanuatu          1980   0.51             8,425
# 186               Venezuela          1999   0.66            37,344
# 187                 Vietnam          1992   0.51            11,344
# 188                  Zambia          1991   0.63            30,696
# 189                Zimbabwe          2013   0.81            55,883
#
#      Executive Power  Legislative Power  Judicial Independence  \
# 0                  6               0.38                      2
# 1                  5               0.43                      5
# 2                  7               0.29                      1
# 3                  6               0.19                      3
# 4                  7               0.19                      2
# 5                  3               0.14                      0
# 6                  3               0.43                      6
# 7                  6               0.29                      4
# 8                  2               0.14                      3
# 9                  3               0.43                      1
# 10                 6               0.29                      3
# 11                 3               0.14                      2
# 12                 7               0.33                      2
# 13                 4               0.33                      5
# 14                 3               0.19                      3
# 15                 7               0.33                      2
# 16                 4               0.38                      3
# 17                 3               0.24                      4
# 18                 4               0.29                      1
# 19                 4               0.29                      5
# 20                 5               0.33                      4
# 21                 2               0.24                      0
# 22                 3               0.10                      4
# 23                 5               0.48                      5
# 24                 7               0.00                      0
# 25                 6               0.52                      6
# 26                 7               0.29                      3
# 27                 7               0.29                      2
# 28                 5               0.52                      2
# 29                 7               0.24                      1
# 30                 2               0.05                      1
# 31                 5               0.43                      1
# 32                 5               0.24                      3
# 33                 4               0.38                      3
# 34                 6               0.33                      4
# 35                 2               0.38                      2
# 36                 5               0.33                      3
# 37                 5               0.24                      1
# 38                 6               0.29                      2
# 39                 5               0.38                      1
# 40                 5               0.29                      1
# 41                 6               0.33                      3
# 42                 6               0.43                      4
# 43                 3               0.38                      1
# 44                 3               0.19                      3
# 45                 4               0.38                      2
# 46                 4               0.43                      1
# 47                 4               0.38                      1
# 48                 3               0.14                      0
# 49                 6               0.29                      4
# 50                 7               0.14                      2
# 51                 6               0.48                      1
# 52                 4               0.38                      3
# 53                 7               0.14                      1
# 54                 3               0.48                      4
# 55                 6               0.38                      2
# 56                 3               0.48                      4
# 57                 3               0.43                      4
# 58                 3               0.48                      1
# 59                 7               0.24                      2
# 60                 7               0.33                      1
# 61                 3               0.33                      6
# 62                 5               0.43                      2
# 63                 5               0.29                      2
# 64                 3               0.29                      4
# 65                 3               0.24                      3
# 66                 3               0.14                      1
# 67                 5               0.38                      1
# 68                 7               0.24                      3
# 69                 3               0.33                      0
# 70                 3               0.19                      3
# 71                 4               0.62                      4
# 72                 4               0.33                      4
# 73                 6               0.33                      2
# 74                 4               0.29                      1
# 75                 4               0.19                      4
# 76                 3               0.33                      2
# 77                 2               0.38                      4
# 78                 4               0.43                      1
# 79                 3               0.38                      3
# 80                 0               0.19                      4
# 81                 4               0.24                      1
# 82                 3               0.10                      1
# 83                 2               0.38                      2
# 84                 7               0.19                      1
# 85                 6               0.14                      3
# 86                 2               0.29                      5
# 87                 2               0.10                      4
# 88                 6               0.29                      5
# 89                 7               0.33                      1
# 90                 4               0.33                      3
# 91                 3               0.43                      2
# 92                 3               0.38                      2
# 93                 6               0.14                      1
# 94                 3               0.14                      3
# 95                 2               0.33                      4
# 96                 5               0.19                      2
# 97                 4               0.38                      3
# 98                 5               0.33                      3
# 99                 3               0.38                      3
# 100                7               0.19                      1
# 101                3               0.43                      4
# 102                4               0.10                      2
# 103                1               0.38                      5
# 104                7               0.24                      2
# 105                4               0.14                      2
# 106                1               0.19                      5
# 107                6               0.33                      1
# 108                3               0.14                      3
# 109                4               0.33                      4
# 110                3               0.19                      4
# 111                5               0.38                      2
# 112                5               0.14                      2
# 113                6               0.33                      4
# 114                5               0.43                      4
# 115                7               0.19                      3
# 116                7               0.14                      2
# 117                3               0.38                      4
# 118                5               0.24                      4
# 119                2               0.14                      1
# 120                3               0.29                      6
# 121                5               0.29                      1
# 122                1               0.19                      4
# 123                4               0.33                      2
# 124                5               0.43                      1
# 125                2               0.38                      4
# 126                1               0.33                      1
# 127                5               0.33                      2
# 128                5               0.05                      1
# 129                5               0.29                      3
# 130                5               0.19                      2
# 131                2               0.33                      2
# 132                3               0.33                      4
# 133                6               0.33                      5
# 134                3               0.33                      4
# 135                6               0.43                      3
# 136                5               0.29                      1
# 137                6               0.29                      1
# 138                7               0.43                      1
# 139                7               0.24                      3
# 140                6               0.33                      4
# 141                3               0.10                      1
# 142                3               0.10                      0
# 143                4               0.14                      4
# 144                5               0.38                      1
# 145                4               0.14                      3
# 146                7               0.29                      2
# 147                3               0.43                      1
# 148                5               0.19                      3
# 149                3               0.19                      5
# 150                4               0.24                      3
# 151                5               0.33                      5
# 152                6               0.52                      5
# 153                1               0.05                      4
# 154                5               0.33                      1
# 155                4               0.29                      5
# 156                5               0.38                      4
# 157                6               0.33                      4
# 158                7               0.38                      1
# 159                5               0.19                      4
# 160                6               0.38                      2
# 161                3               0.24                      2
# 162                2               0.29                      5
# 163                5               0.52                      1
# 164                1               0.33                      1
# 165                7               0.33                      0
# 166                2               0.33                      4
# 167                5               0.24                      3
# 168                3               0.33                      2
# 169                5               0.14                      1
# 170                3               0.33                      2
# 171                6               0.29                      1
# 172                4               0.29                      1
# 173                3               0.10                      3
# 174                7               0.38                      2
# 175                5               0.38                      4
# 176                4               0.14                      1
# 177                2               0.19                      2
# 178                1               0.38                      3
# 179                2               0.24                      5
# 180                6               0.48                      4
# 181                4               0.10                      2
# 182                0               0.09                      3
# 183                5               0.48                      1
# 184                5               0.33                      2
# 185                6               0.29                      4
# 186                6               0.38                      1
# 187                2               0.43                      0
# 188                4               0.10                      4
# 189                6               0.33                      4
#
#      Number of Rights                                           Preamble
# 0                  37  In the name of Allah, the Most Beneficent, the...
# 1                  77  We, the people of Albania, proud and aware of ...
# 2                  36  The Algerian people are a free people; and the...
# 3                  51  The Andorran People, with full liberty and ind...
# 4                  80  We, the people of Angola, through its lawful r...
# 5                  39   WHEREAS the People of Antigua and Barbuda-pro...
# 6                  51  We, the representatives of the people of the A...
# 7                  82  The Armenian People, accepting as a basis the ...
# 8                  11                                                NaN
# 9                  15                                                NaN
# 10                 72   The Azerbaijan people, continuing the traditi...
# 11                 39  Whereas Four hundred and eighty-one years ago ...
# 12                 48  In the name of God, the Merciful, the Compassi...
# 13                 49  We, the people of Bangladesh, having proclaime...
# 14                 40   Whereas the love of free institutions and of ...
# 15                 62  We, the People of the Republic of Belarus, (of...
# 16                 35  In the name of the Belgian people, the Nationa...
# 17                 46   WHEREAS the people of Belize-affirm that the ...
# 18                 43   Dahomey, proclaimed a Republic on December 4,...
# 19                 44  WE, the people of Bhutan: BLESSED by the Tripl...
# 20                 88  In ancient times mountains arose, rivers moved...
# 21                 28  Based on respect for human dignity, liberty, a...
# 22                 36                                                NaN
# 23                 79  We the representatives of the Brazilian People...
# 24                  2  In the name of GOD, the Compassionate, the Mer...
# 25                 70  We, the Members of the Seventh Grand National ...
# 26                 54   We, the Sovereign People of Burkina Faso:CONS...
# 27                 55   We the people of Burundi, Conscious of our re...
# 28                 52  WE, THE PEOPLE OF CAMBODIA Having known grand ...
# 29                 36   We, the people of Cameroon, Proud of our ling...
# 30                 36  CONSTITUTION ACT 1867&nbsp;&gt;&nbsp;VII. JUDI...
# 31                 87  The Proclamation of National Independence is o...
# 32                 48  The Central African People Proud of their nati...
# 33                 44   Chad, proclaimed a Republic on 28 November 19...
# 34                 46  We the people of Chile, responsible for her hi...
# 35                 33  China is one of the countries with the longest...
# 36                 76  The people of Colombia, In the exercise of the...
# 37                 23   The Comorian people solemnly affirm their wil...
# 38                 55   The morning after the accession of the Congo ...
# 39                 58  We, the Congolese People, United by destiny an...
# 40                 55  We, the Representatives of the People of Costa...
# 41                 36   The People of Côte d’Ivoire, Conscious of the...
# 42                 69  I Historical Foundations I Historical Foundati...
# 43                 45  WE, CUBAN CITIZENS, heirs and continuators of ...
# 44                 52                                                NaN
# 45                 57  We, the citizens of the Czech Republic in Bohe...
# 46                 21                                                NaN
# 47                 26  In the name of God All-Powerful The Djiboutian...
# 48                 38   Whereas the People of Dominica—have affirmed ...
# 49                 75  We, representatives of the Dominican people, f...
# 50                 99  We women and men, the sovereign people of Ecua...
# 51                 65  In the Name of God, Most Gracious, Most Mercif...
# 52                 61  WE, THE REPRESENTATIVES OF THE SALVADORIAN PEO...
# 53                 33  We, the people of Equatorial Guinea, conscious...
# 54                 54  We, the people of Eritrea, united in a common ...
# 55                 66  The Esthonian people, with unshaken faith and ...
# 56                 77  We, the Nations, Nationalities and Peoples of ...
# 57                 64  WE, THE PEOPLE OF FIJI, RECOGNISING the indige...
# 58                 48                                                NaN
# 59                 13                                                NaN
# 60                 40  The Gabonese people, conscious of its responsi...
# 61                 62  In the name of God, the Almighty. We the peopl...
# 62                 63  The citizens of Georgia, whose firm will is to...
# 63                 48  Conscious of their responsibility before God a...
# 64                 61  IN THE NAME OF THE ALMIGHTY GOD We the People ...
# 65                 56  In the name of the Holy and Consubstantial and...
# 66                 39   Whereas the people of Grenadahave affirmed th...
# 67                 63  INVOKING THE NAME OF GOD We, the representativ...
# 68                 44   By its vote of 28 September 1958, the People ...
# 69                 47  In an exemplary manner, the PAIGC, having been...
# 70                 57  WE THE PEOPLE OF THE CO-OPERATIVE REPUBLIC OF ...
# 71                 49  The Haitian people proclaim this Constitution:...
# 72                 68  We, the representatives elected by the soverei...
# 73                 68   WE, THE MEMBERS OF THE HUNGARIAN NATION, at t...
# 74                 40  We, the people of Iceland, wish to create a ju...
# 75                 44  WE, THE PEOPLE OF INDIA, having solemnly resol...
# 76                 32  Whereas independence is the inalienable right ...
# 77                 45   In the Name of Allah, the Compassionate, the ...
# 78                 53  In the name of God, the Most merciful, the Mos...
# 79                 31  In the Name of the Most Holy Trinity, from Who...
# 80                  6                                                NaN
# 81                 56                                                NaN
# 82                 35                                                NaN
# 83                 48  We, the Japanese people, acting through our du...
# 84                 35  We, Talal the First, King of the Hashemite Kin...
# 85                 57  We, the people of Kazakhstan, united by common...
# 86                 72  We, the people of Kenya - ACKNOWLEDGING the su...
# 87                 41   We the people of Kiribati, acknowledging God ...
# 88                 73  We, the people of Kosovo, Determined to build ...
# 89                 38  In the Name of God the Compassionate, the Merc...
# 90                 69  We, the people of Kyrgyzstan, Paying tribute t...
# 91                 27  The multi-ethnic Lao people have existed and d...
# 92                 44  The people of Latvia, in freely elected Consti...
# 93                 14  PART I BASIC PROVISIONS PART I BASIC PROVISION...
# 94                 55                                                NaN
# 95                 49  We the People of the Republic of Liberia: Ackn...
# 96                 29  We, John II, by the Grace of God, Prince Regna...
# 97                 66  THE LITHUANIAN NATION – having created the Sta...
# 98                 27                                                NaN
# 99                 68   Taking as the points of departure the histori...
# 100                46   The sovereign Malagasy People, Affirming its ...
# 101                66  THE PEOPLE OF MALAWI— recognizing the sanctity...
# 102                31                                                NaN
# 103                74                                                NaN
# 104                43   The sovereign people of Mali, strong from the...
# 105                46                                                NaN
# 106                46  WE, THE PEOPLE OF THE REPUBLIC OF THE MARSHALL...
# 107                31   Trusting in the omnipotence of Allah, the Mau...
# 108                36                                                NaN
# 109                81                                                NaN
# 110                36  WE, THE PEOPLE OF MICRONESIA, exercising our i...
# 111                65  WE, the plenipotentiary representatives of the...
# 112                26                                                NaN
# 113                62   We, the people of Mongolia:consolidating and ...
# 114                76  Stemming from: The decision of the citizens of...
# 115                53   With fidelity to its irreversible choice to c...
# 116                64  Meeting the age-old desires of our people, the...
# 117                39   Myanmar is a Nation with magnificent historic...
# 118                59   Whereas recognition of the inherent dignity a...
# 119                34  WHEREAS we the people of Nauru acknowledge God...
# 120                56  WE, THE SOVEREIGNTY AND STATE AUTHORITY INHERE...
# 121                26                                                NaN
# 122                40  Legislature Act 1908&nbsp;&gt;&nbsp;Amendment ...
# 123                77  WE, Representatives of the People of Nicaragua...
# 124                46   We, The Sovereign Nigerien PeopleResolved to ...
# 125                57  We the people of the Federal Republic of Niger...
# 126                35  The Democratic People’s Republic of Korea is a...
# 127                39                                                NaN
# 128                39                                                NaN
# 129                45  Whereas sovereignty over the entire Universe b...
# 130                63  With the ultimate purpose to strengthen the Na...
# 131                53   WE, THE PEOPLE OF PAPUA NEW GUINEA-united in ...
# 132                74  The Paraguayan People, through their legitimat...
# 133                72  The Democratic Constituent Congress invoking A...
# 134                63  We, the sovereign Filipino people, imploring t...
# 135                60  Having regard for the existence and future of ...
# 136                87  On the 25th of April 1974 the Armed Forces Mov...
# 137                32                                                NaN
# 138                71                                                NaN
# 139                64  The declaration of rights of the laboring and ...
# 140                53   We, the People of Rwanda,In the wake of the g...
# 141                36   WHEREAS the People of Saint Christopher and N...
# 142                41   WHEREAS the People of Saint Lucia-affirm thei...
# 143                37  IN THE HOLY NAME OF GOD, THE ALMIGHTY, THE EVE...
# 144                62  During five centuries the Sao Tomean People we...
# 145                15                                                NaN
# 146                33   The sovereign People of Senegal, PROFOUNDLY a...
# 147                88  Considering the state tradition of the Serbian...
# 148                61   We, the People of Seychelles, GRATEFUL to Alm...
# 149                56                                                NaN
# 150                18                                                NaN
# 151                74                                                NaN
# 152                72  Proceeding from the Basic Constitutional Chart...
# 153                41   We the people of Solomon Islands, proud of th...
# 154                57                                                NaN
# 155                60   We, the people of South Africa, Recognise the...
# 156                56  We the people of Korea, proud of a resplendent...
# 157                48  We, the People of South Sudan, Grateful to the...
# 158                60  In the name of God Almighty, Father, Son, and ...
# 159                40  The PEOPLE OF SRI LANKA having, by their Manda...
# 160                49  We the people of the Sudan Grateful to Almight...
# 161                48                                                NaN
# 162                61  Whereas We the People of the Kingdom of Swazil...
# 163                34                                                NaN
# 164                65  In the name of God Almighty! We, the Swiss Peo...
# 165                42  Arab civilization, which is part of human heri...
# 166                29  The National Constituent Assembly of the Repub...
# 167                65  WE, THE PEOPLE OF TAJIKISTAN, As an inseparabl...
# 168                38  WHEREAS WE, the people of the United Republic ...
# 169                 2  SOMDET PHRA PARAMINTHARAMAHA BHUMIBOL ADUYADEJ...
# 170                67  The independence of East Timor, proclaimed by ...
# 171                49  We, the Togolese people, placing ourselves und...
# 172                20  Granted by His Majesty King George Tupou I on ...
# 173                33   Whereas the People of Trinidad and Tobago—hav...
# 174                45  In the Name of God, the Merciful, the Compassi...
# 175                68  This Constitution, which affirms the eternal e...
# 176                56  We, the people of Turkmenistan, based on our i...
# 177                40   WHEREAS in adopting the Independence Constitu...
# 178                35  We the People of the United States, in Order t...
# 179                70  WE THE PEOPLE OF UGANDA: RECALLING our history...
# 180                70  The Verkhovna Rada of Ukraine, on behalf of th...
# 181                32  We, the Rulers of the Emirates of Abu Dhabi, D...
# 182                44  Magna Carta 1297 THE GREAT CHARTER OF THE LIBE...
# 183                54                                                NaN
# 184                55  The people of Uzbekistan, solemnly declaring t...
# 185                28  WE the people of Vanuatu, PROUD of our struggl...
# 186                82  The people of Venezuela, exercising their powe...
# 187                45  In the course of their millennia-old history, ...
# 188                50  WE, THE PEOPLE OF ZAMBIA: ACKNOWLEDGE the supr...
# 189                74  We the people of Zimbabwe, United in our diver...

# %%
def clean_text(text):
    text = text.lower()
    text = re.sub(r'@\w+|#\w+', '', text)
    text = re.sub(r'[^\w\s]', '', text)
    text = re.sub(r'\d+', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# eliminamos las filas que no tienen preambulos (31/190)
df_const = df_const.dropna()
df_const.loc[:,"Preamble"] = df_const["Preamble"].apply(clean_text)

# %%
exe_included_counts = df_const['Executive Power'].value_counts(dropna=False)
print(exe_included_counts)

# 0(1) + 1(6) + 2(16) + 3(33) + 4(22) = 78
# 5(29) + 6(29) + 7(23) = 81
# Out:
# Executive Power
# 3    33
# 6    29
# 5    29
# 7    23
# 4    22
# 2    16
# 1     6
# 0     1
# Name: count, dtype: int64

# %% [markdown]
# <div style="background:#FFFFE0;padding:20px;color:#000000;margin-top:10px;">
# Creando nuevas columnas para nivel poder ejecutivo:
# </div>

# %%
df_const.loc[:,"nivel_poder_ejecutivo"] = df_const["Executive Power"].apply(lambda x:1 if x > 4 else 0)

df_const.loc[:,"nivel_poder_ejecutivo"].value_counts(dropna=False)
# Out:
# C:\Users\cadet\AppData\Local\Temp\ipykernel_31000\2302771578.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_const.loc[:,"nivel_poder_ejecutivo"] = df_const["Executive Power"].apply(lambda x:1 if x > 4 else 0)
# nivel_poder_ejecutivo
# 1    81
# 0    78
# Name: count, dtype: int64

# %%
df_const.count()
# Out:
# Country                  159
# Year Enacted             159
# Scope                    159
# Length (in Words)        159
# Executive Power          159
# Legislative Power        159
# Judicial Independence    159
# Number of Rights         159
# Preamble                 159
# nivel_poder_ejecutivo    159
# dtype: int64

# %% [markdown]
# <div style="background:#FFFFE0;padding:20px;color:#000000;margin-top:10px;">
# Creando un dataframe manual de entrenamiento/prueba:
#
# 50:50 cuyos niveles de poder ejecutivo son 1 y 0 para entrenamiento.
#
# 22:22 cuyos niveles de poder ejecutivo son 1 y 0 para probar.
#
# </div>

# %%
# Mejor usar datos con 50/50 probabilidad exacta de ser bajo o alto nivel de poder ejecutivo para nuestros modelos

# Paso 1: separar por clase
df_0 = df_const[df_const["nivel_poder_ejecutivo"] == 0]
df_1 = df_const[df_const["nivel_poder_ejecutivo"] == 1]

# Paso 2: seleccionar primeros 50 de cada clase para el primer conjunto
df_0_train = df_0.iloc[:50]
df_1_train = df_1.iloc[:50]

# Paso 3: seleccionar los siguientes 22 de cada clase para el segundo conjunto
df_0_test = df_0.iloc[50:72]
df_1_test = df_1.iloc[50:72]

# Paso 4: concatenar conjuntos
df_train = pd.concat([df_0_train, df_1_train])
df_test = pd.concat([df_0_test, df_1_test])

# Paso 5: unir todo en un solo DataFrame
df_const_complete = pd.concat([df_train, df_test]).reset_index(drop=True)

# %%
df_const_complete.count()
# Out:
# Country                  144
# Year Enacted             144
# Scope                    144
# Length (in Words)        144
# Executive Power          144
# Legislative Power        144
# Judicial Independence    144
# Number of Rights         144
# Preamble                 144
# nivel_poder_ejecutivo    144
# dtype: int64

# %% [markdown]
# <div style="background:#FFFFE0;padding:20px;color:#000000;margin-top:10px;">
# Entrenando datos basado en dataset "completo"
# </div>

# %%
# Para pruebas de los datos completos
preamble = df_const_complete["Preamble"]
poder = df_const_complete["nivel_poder_ejecutivo"]

vectorizador = TfidfVectorizer()
X = vectorizador.fit_transform(preamble)
y = poder


#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y)

# %%
split_index = int(0.7 * X.shape[0])
X_train = X[:split_index]
X_test = X[split_index:]

y_train = y.iloc[:split_index]
y_test = y.iloc[split_index:]

# %%
X_train
# Out:
# <100x5344 sparse matrix of type '<class 'numpy.float64'>'
# 	with 14790 stored elements in Compressed Sparse Row format>

# %%
X_test
# Out:
# <44x5344 sparse matrix of type '<class 'numpy.float64'>'
# 	with 6307 stored elements in Compressed Sparse Row format>

# %% [markdown]
# <div style="background:#FFFFE0;padding:20px;color:#000000;margin-top:10px;">
# Prueba del modelo de Naive Bayes
# </div>

# %%
# Entrenando el modelo Naive Bayes que es uno de los más usados para clasificación de texto
nb_model = MultinomialNB()
nb_model.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
# Haciendo predicciones con los datos de prueba
y_pred_nb = nb_model.predict(X_test)

# %%
# Imprimiendo el accuracy y otras métricas importantes como precision, recall y f1-score
print("Accuracy Naive Bayes:", accuracy_score(y_test, y_pred_nb))
print(classification_report(y_test, y_pred_nb))
# Out:
# Accuracy Naive Bayes: 0.6136363636363636
#               precision    recall  f1-score   support
#
#            0       0.58      0.82      0.68        22
#            1       0.69      0.41      0.51        22
#
#     accuracy                           0.61        44
#    macro avg       0.64      0.61      0.60        44
# weighted avg       0.64      0.61      0.60        44

# %%
# Mostrando la matriz de confusión
ConfusionMatrixDisplay.from_predictions(y_test, y_pred_nb)

# %% [markdown]
# <div style="background:#FFFFE0;padding:20px;color:#000000;margin-top:10px;">
# Prueba de Regresión Logística
# </div>

# %%
lr_model = LogisticRegression(max_iter=1000)
lr_model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
# Haciendo las predicciones y muestrando las métricas igual que antes
y_pred_lr = lr_model.predict(X_test)

# %%
print("Accuracy Regresion Logistica:", accuracy_score(y_test, y_pred_lr))
print(classification_report(y_test, y_pred_lr))
ConfusionMatrixDisplay.from_predictions(y_test, y_pred_lr)
# Out:
# Accuracy Regresion Logistica: 0.6136363636363636
#               precision    recall  f1-score   support
#
#            0       0.58      0.82      0.68        22
#            1       0.69      0.41      0.51        22
#
#     accuracy                           0.61        44
#    macro avg       0.64      0.61      0.60        44
# weighted avg       0.64      0.61      0.60        44

# %% [markdown]
# <div style="background:#FFFFE0;padding:20px;color:#000000;margin-top:10px;">
# Prueba de Árbol de Decisión
# </div>

# %%
# Finalmente pruebando un modelo basado en arboles (Decision Tree)
# Entrenando el arbol con los mismos datos
tree_model = DecisionTreeClassifier()
tree_model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Prediciendo y mostrando las metricas
y_pred_tree = tree_model.predict(X_test)

# %%
print("Accuracy Árbol de Decisión:", accuracy_score(y_test, y_pred_tree))
print(classification_report(y_test, y_pred_tree))
ConfusionMatrixDisplay.from_predictions(y_test, y_pred_tree)
# Out:
# Accuracy Árbol de Decisión: 0.5454545454545454
#               precision    recall  f1-score   support
#
#            0       0.55      0.50      0.52        22
#            1       0.54      0.59      0.57        22
#
#     accuracy                           0.55        44
#    macro avg       0.55      0.55      0.54        44
# weighted avg       0.55      0.55      0.54        44

# %% [markdown]
# <div style="background:#FFFFE0;padding:20px;color:#000000;margin-top:10px;">
# Prueba de Maquinas de Clasificacion de Soporte de Vectores Lineales (LinearSVC)
# </div>

# %%
lsvc = LinearSVC(dual = False)

# %%
lsvc.fit(X_train, y_train)
# Out:
# LinearSVC(dual=False)

# %%
y_pred_class=lsvc.predict(X_test)

# %%
print("Accuracy LinearSVC:", accuracy_score(y_test, y_pred_class))
print(classification_report(y_test, y_pred_class))
ConfusionMatrixDisplay.from_predictions(y_test, y_pred_class)
# Out:
# Accuracy LinearSVC: 0.6363636363636364
#               precision    recall  f1-score   support
#
#            0       0.59      0.86      0.70        22
#            1       0.75      0.41      0.53        22
#
#     accuracy                           0.64        44
#    macro avg       0.67      0.64      0.62        44
# weighted avg       0.67      0.64      0.62        44

# %% [markdown]
# <div style="background:#FFFFE0;padding:20px;color:#000000;margin-top:10px;">
# Prueba de Maquinas de Clasificacion de Bosque Aleatorio
# </div>

# %%
# Finalmente pruebando un modelo basado en arboles (Decision Tree)
# Entrenando el arbol con los mismos datos
tree_model = RandomForestClassifier()
tree_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
# Prediciendo y mostrando las metricas
y_pred_rand = tree_model.predict(X_test)

# %%
print("Accuracy Random F:", accuracy_score(y_test, y_pred_rand))
print(classification_report(y_test, y_pred_rand))
ConfusionMatrixDisplay.from_predictions(y_test, y_pred_rand)
# Out:
# Accuracy Random F: 0.7272727272727273
#               precision    recall  f1-score   support
#
#            0       0.66      0.95      0.78        22
#            1       0.92      0.50      0.65        22
#
#     accuracy                           0.73        44
#    macro avg       0.79      0.73      0.71        44
# weighted avg       0.79      0.73      0.71        44

# %%
print("Resumen de Accuracies:")
print("Naive Bayes:        ", accuracy_score(y_test, y_pred_nb))
print("Regresión Logística:", accuracy_score(y_test, y_pred_lr))
print("Árbol de Decisión:  ", accuracy_score(y_test, y_pred_tree))
print("Linear Vector Machine:  ", accuracy_score(y_test, y_pred_class))
print("Random Forest Classifier:  ", accuracy_score(y_test, y_pred_rand))
# Out:
# Resumen de Accuracies:
# Naive Bayes:         0.6136363636363636
# Regresión Logística: 0.6136363636363636
# Árbol de Decisión:   0.5
# Linear Vector Machine:   0.6363636363636364
# Random Forest Classifier:   0.7272727272727273

# %% [markdown]
# <div style="background:#FFFFE0;padding:20px;color:#000000;margin-top:10px;">
# Validación cruzada basados en los modelos de Naive Bayes, Regresión Logística, Árbol de Decisión, Linear Vector Machine y Random Forest Classifier
# </div>

# %%
from sklearn.model_selection import cross_val_score, cross_validate, StratifiedKFold

preamble = df_const_complete["Preamble"]
poder_eje = df_const_complete["nivel_poder_ejecutivo"]

vectorizador = TfidfVectorizer()
X = vectorizador.fit_transform(preamble)
y = poder_eje

# %%
# Definimos el esquema de validación cruzada estratificada con 10 folds
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=None)

# %%
# Obtenemos los puntajes de accuracy en cada fold

modelo_nb = MultinomialNB()

scores_nb = cross_val_score(modelo_nb, X, y, cv=skf, scoring='accuracy')

# Mostramos resultados
print("Naive Bayes Accuracy en cada fold:", scores_nb)
print("Naive Bayes Accuracy promedio: {:.4f}".format(scores_nb.mean()))
# Out:
# Naive Bayes Accuracy en cada fold: [0.73333333 0.46666667 0.73333333 0.66666667 0.64285714 0.78571429
#  0.64285714 0.78571429 0.5        0.85714286]
# Naive Bayes Accuracy promedio: 0.6814

# %%
# Modelo 2: Regresión Logística
# Ahora evaluamos el modelo de regresión logística con el mismo esquema de validación cruzada.

modelo_lr = LogisticRegression(max_iter=1000)

scores_lr = cross_val_score(modelo_lr, X, y, cv=skf, scoring='accuracy')

print("Regresión Logística Accuracy en cada fold:", scores_lr)
print("Regresión Logística Accuracy promedio: {:.4f}".format(scores_lr.mean()))
# Out:
# Regresión Logística Accuracy en cada fold: [0.73333333 0.66666667 0.6        0.86666667 0.42857143 0.57142857
#  0.5        0.71428571 0.71428571 0.64285714]
# Regresión Logística Accuracy promedio: 0.6438

# %%
# Modelo 3: Árbol de Decisión
# Finalmente evaluamos el modelo de árbol de decisión usando validación cruzada.

modelo_dt = DecisionTreeClassifier()

scores_dt = cross_val_score(modelo_dt, X, y, cv=skf, scoring='accuracy')

print("Árbol de Decisión Accuracy en cada fold:", scores_dt)
print("Árbol de Decisión Accuracy promedio: {:.4f}".format(scores_dt.mean()))
# Out:
# Árbol de Decisión Accuracy en cada fold: [0.6        0.73333333 0.53333333 0.6        0.71428571 0.64285714
#  0.85714286 0.42857143 0.64285714 0.64285714]
# Árbol de Decisión Accuracy promedio: 0.6395

# %%
# Modelo 4: Árbol de Decisión
# Finalmente evaluamos el modelo de árbol de decisión usando validación cruzada.
# Maquinas de Clasificacion de Soporte de Vectores Lineales (LinearSVC)


lsvc_dt = LinearSVC(dual = False)

scores_dt = cross_val_score(lsvc_dt, X, y, cv=skf, scoring='accuracy')

print("Linear Vector Machine Accuracy en cada fold:", scores_dt)
print("Linear Vector Machine Accuracy promedio: {:.4f}".format(scores_dt.mean()))
# Out:
# Linear Vector Machine Accuracy en cada fold: [0.6        0.53333333 0.73333333 0.66666667 0.71428571 0.85714286
#  0.5        0.57142857 0.71428571 0.64285714]
# Linear Vector Machine Accuracy promedio: 0.6533

# %%
# Modelo 5: Bosque Aleatorio
# Finalmente evaluamos el modelo de árbol de decisión usando validación cruzada.

modelo_rf = RandomForestClassifier()

scores_rf = cross_val_score(modelo_rf, X, y, cv=skf, scoring='accuracy')

print("Random Forest Classifier Accuracy en cada fold:", scores_rf)
print("Random Forest Classifier Accuracy promedio: {:.4f}".format(scores_rf.mean()))
# Out:
# Random Forest Classifier Accuracy en cada fold: [0.86666667 0.73333333 0.73333333 0.53333333 0.64285714 0.42857143
#  0.57142857 0.71428571 0.85714286 0.78571429]
# Random Forest Classifier Accuracy promedio: 0.6867

# %% [markdown]
# <div style="background:#FFFFE0;padding:20px;color:#000000;margin-top:10px;">
# Creando un dataframe manual de entrenamiento/prueba (en vivo):
#
# 50:50 cuyos niveles de poder ejecutivo son 1 y 0 para entrenamiento.
#
# 5:5 cuyos niveles de poder ejecutivo son 1 y 0 para probar.
#
# </div>

# %%
# Paso 1: separar por clase
df_0 = df_const[df_const["nivel_poder_ejecutivo"] == 0]
df_1 = df_const[df_const["nivel_poder_ejecutivo"] == 1]

# Paso 2: seleccionar primeros 50 de cada clase para entrenamiento
df_0_train = df_0.iloc[:50]
df_1_train = df_1.iloc[:50]

# Paso 3: seleccionar últimos 5 de cada clase para probar
df_0_test = df_0.tail(5)
df_1_test = df_1.tail(5)

# Paso 4: crear DataFrames de entrenamiento y prueba
df_train = pd.concat([df_0_train, df_1_train])
df_test = pd.concat([df_0_test, df_1_test])

# Paso 5: unir en un solo DataFrame 
df_prueba = pd.concat([df_train, df_test]).reset_index(drop=True)

# %%
#df_prueba = pd.concat([df_const_complete, df_const_prueba_complete])

preamble = df_prueba["Preamble"]
poder = df_prueba["nivel_poder_ejecutivo"]

vectorizador = TfidfVectorizer()
X = vectorizador.fit_transform(preamble)
y = poder


#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.0909, stratify=y)

split_index = int(0.9091 * X.shape[0])
X_train = X[:split_index]
X_test = X[split_index:]

y_train = y.iloc[:split_index]
y_test = y.iloc[split_index:]

# %%
X_train
# Out:
# <100x4650 sparse matrix of type '<class 'numpy.float64'>'
# 	with 14790 stored elements in Compressed Sparse Row format>

# %%
X_test
# Out:
# <10x4650 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1123 stored elements in Compressed Sparse Row format>

# %% [markdown]
# <div style="background:#FFFFE0;padding:20px;color:#000000;margin-top:10px;">
# Prueba del modelo de Naive Bayes (en vivo)
# </div>

# %%
# Entrenando el modelo Naive Bayes que es uno de los más usados para clasificación de texto
nb_model = MultinomialNB()
nb_model.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
# Haciendo predicciones con los datos de prueba
y_pred_nb = nb_model.predict(X_test)

# %%
# Imprimiendo el accuracy y otras métricas importantes como precision, recall y f1-score
print("Accuracy Naive Bayes:", accuracy_score(y_test, y_pred_nb))
print(classification_report(y_test, y_pred_nb))
# Out:
# Accuracy Naive Bayes: 0.8
#               precision    recall  f1-score   support
#
#            0       0.71      1.00      0.83         5
#            1       1.00      0.60      0.75         5
#
#     accuracy                           0.80        10
#    macro avg       0.86      0.80      0.79        10
# weighted avg       0.86      0.80      0.79        10

# %%
# Mostrando la matriz de confusión
ConfusionMatrixDisplay.from_predictions(y_test, y_pred_nb)

# %% [markdown]
# <div style="background:#FFFFE0;padding:20px;color:#000000;margin-top:10px;">
# Prueba de Regresión Logística (en vivo)
# </div>

# %%
lr_model = LogisticRegression(max_iter=1000)
lr_model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
# Haciendo las predicciones y muestrando las métricas igual que antes
y_pred_lr = lr_model.predict(X_test)

# %%
print("Accuracy Regresión Logística:", accuracy_score(y_test, y_pred_lr))
print(classification_report(y_test, y_pred_lr))
ConfusionMatrixDisplay.from_predictions(y_test, y_pred_lr)
# Out:
# Accuracy Regresión Logística: 0.8
#               precision    recall  f1-score   support
#
#            0       0.71      1.00      0.83         5
#            1       1.00      0.60      0.75         5
#
#     accuracy                           0.80        10
#    macro avg       0.86      0.80      0.79        10
# weighted avg       0.86      0.80      0.79        10

# %% [markdown]
# <div style="background:#FFFFE0;padding:20px;color:#000000;margin-top:10px;">
# Prueba de Árbol de Decisión (en vivo)
# </div>

# %%
# Finalmente pruebando un modelo basado en arboles (Decision Tree)
# Entrenando el arbol con los mismos datos
tree_model = DecisionTreeClassifier()
tree_model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Prediciendo y mostrando las metricas
y_pred_tree = tree_model.predict(X_test)

# %%
print("Accuracy Árbol de Decisión:", accuracy_score(y_test, y_pred_tree))
print(classification_report(y_test, y_pred_tree))
ConfusionMatrixDisplay.from_predictions(y_test, y_pred_tree)
# Out:
# Accuracy Árbol de Decisión: 0.5
#               precision    recall  f1-score   support
#
#            0       0.50      0.60      0.55         5
#            1       0.50      0.40      0.44         5
#
#     accuracy                           0.50        10
#    macro avg       0.50      0.50      0.49        10
# weighted avg       0.50      0.50      0.49        10

# %% [markdown]
# <div style="background:#FFFFE0;padding:20px;color:#000000;margin-top:10px;">
# Prueba de Maquinas de Clasificacion de Soporte de Vectores Lineales (LinearSVC) (en vivo)
# </div>

# %%
lsvc = LinearSVC(dual = False)

# %%
lsvc.fit(X_train, y_train)
# Out:
# LinearSVC(dual=False)

# %%
y_pred_class=lsvc.predict(X_test)

# %%
print("Accuracy LinearSVC:", accuracy_score(y_test, y_pred_class))
print(classification_report(y_test, y_pred_class))
ConfusionMatrixDisplay.from_predictions(y_test, y_pred_class)
# Out:
# Accuracy LinearSVC: 0.8
#               precision    recall  f1-score   support
#
#            0       0.71      1.00      0.83         5
#            1       1.00      0.60      0.75         5
#
#     accuracy                           0.80        10
#    macro avg       0.86      0.80      0.79        10
# weighted avg       0.86      0.80      0.79        10

# %% [markdown]
# <div style="background:#FFFFE0;padding:20px;color:#000000;margin-top:10px;">
# Prueba de Maquinas de Clasificacion de Bosque Aleatorio
# </div>

# %%
# Finalmente pruebando un modelo basado en arboles (Decision Tree)
# Entrenando el arbol con los mismos datos
tree_model = RandomForestClassifier()
tree_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
# Prediciendo y mostrando las metricas
y_pred_rand = tree_model.predict(X_test)

# %%
print("Accuracy Random F:", accuracy_score(y_test, y_pred_rand))
print(classification_report(y_test, y_pred_rand))
ConfusionMatrixDisplay.from_predictions(y_test, y_pred_rand)
# Out:
# Accuracy Random F: 0.7
#               precision    recall  f1-score   support
#
#            0       0.67      0.80      0.73         5
#            1       0.75      0.60      0.67         5
#
#     accuracy                           0.70        10
#    macro avg       0.71      0.70      0.70        10
# weighted avg       0.71      0.70      0.70        10

# %%
print("Resumen de Accuracies:")
print("Naive Bayes:        ", accuracy_score(y_test, y_pred_nb))
print("Regresión Logística:", accuracy_score(y_test, y_pred_lr))
print("Árbol de Decisión:  ", accuracy_score(y_test, y_pred_tree))
print("Linear Vector Machine:  ", accuracy_score(y_test, y_pred_class))
print("Random Forest Classifier:  ", accuracy_score(y_test, y_pred_rand))
# Out:
# Resumen de Accuracies:
# Naive Bayes:         0.8
# Regresión Logística: 0.8
# Árbol de Decisión:   0.5
# Linear Vector Machine:   0.8
# Random Forest Classifier:   0.7

# %% [markdown]
# <div style="background:#FFFFE0;padding:20px;color:#000000;margin-top:10px;">
# Validación cruzada basados en los modelos de Naive Bayes, Regresión Logística, Árbol de Decisión, Linear Vector Machine y Random Forest Classifier
# </div>

# %%
from sklearn.model_selection import cross_val_score, cross_validate, StratifiedKFold

preamble = df_prueba["Preamble"]
poder_eje = df_prueba["nivel_poder_ejecutivo"]

vectorizador = TfidfVectorizer()
X = vectorizador.fit_transform(preamble)
y = poder_eje

# %%
# Definimos el esquema de validación cruzada estratificada con 5 folds
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=None)

# %%
# Obtenemos los puntajes de accuracy en cada fold

modelo_nb = MultinomialNB()

scores_nb = cross_val_score(modelo_nb, X, y, cv=skf, scoring='accuracy')

# Mostramos resultados
print("Naive Bayes Accuracy en cada fold:", scores_nb)
print("Naive Bayes Accuracy promedio: {:.4f}".format(scores_nb.mean()))
# Out:
# Naive Bayes Accuracy en cada fold: [0.72727273 0.72727273 0.72727273 0.72727273 0.54545455 0.72727273
#  0.63636364 0.81818182 0.81818182 0.63636364]
# Naive Bayes Accuracy promedio: 0.7091

# %%
# Modelo 2: Regresión Logística
# Ahora evaluamos el modelo de regresión logística con el mismo esquema de validación cruzada.

modelo_lr = LogisticRegression(max_iter=1000)

scores_lr = cross_val_score(modelo_lr, X, y, cv=skf, scoring='accuracy')

print("Regresión Logística Accuracy en cada fold:", scores_lr)
print("Regresión Logística Accuracy promedio: {:.4f}".format(scores_lr.mean()))
# Out:
# Regresión Logística Accuracy en cada fold: [0.63636364 0.63636364 0.36363636 0.63636364 0.72727273 0.63636364
#  0.54545455 0.72727273 0.54545455 0.90909091]
# Regresión Logística Accuracy promedio: 0.6364

# %%
# Modelo 3: Árbol de Decisión
# Finalmente evaluamos el modelo de árbol de decisión usando validación cruzada.

modelo_dt = DecisionTreeClassifier()

scores_dt = cross_val_score(modelo_dt, X, y, cv=skf, scoring='accuracy')

print("Árbol de Decisión Accuracy en cada fold:", scores_dt)
print("Árbol de Decisión Accuracy promedio: {:.4f}".format(scores_dt.mean()))
# Out:
# Árbol de Decisión Accuracy en cada fold: [0.45454545 0.54545455 0.63636364 0.81818182 0.63636364 0.63636364
#  0.45454545 0.54545455 0.54545455 0.54545455]
# Árbol de Decisión Accuracy promedio: 0.5818

# %%
# Modelo 4: Árbol de Decisión
# Finalmente evaluamos el modelo de árbol de decisión usando validación cruzada.
# Maquinas de Clasificacion de Soporte de Vectores Lineales (LinearSVC)


lsvc_dt = LinearSVC(dual = False)

scores_dt = cross_val_score(lsvc_dt, X, y, cv=skf, scoring='accuracy')

print("Linear Vector Machine Accuracy en cada fold:", scores_dt)
print("Linear Vector Machine Accuracy promedio: {:.4f}".format(scores_dt.mean()))
# Out:
# Linear Vector Machine Accuracy en cada fold: [0.81818182 0.72727273 0.63636364 0.72727273 0.63636364 0.54545455
#  0.81818182 0.63636364 0.63636364 0.54545455]
# Linear Vector Machine Accuracy promedio: 0.6727

# %%
# Modelo 3: Bosque Aleatorio
# Finalmente evaluamos el modelo de árbol de decisión usando validación cruzada.

modelo_rf = RandomForestClassifier()

scores_rf = cross_val_score(modelo_rf, X, y, cv=skf, scoring='accuracy')

print("Random Forest Classifier Accuracy en cada fold:", scores_rf)
print("Random Forest Classifier Accuracy promedio: {:.4f}".format(scores_rf.mean()))
# Out:
# Random Forest Classifier Accuracy en cada fold: [0.54545455 0.54545455 0.45454545 0.72727273 0.90909091 0.54545455
#  0.72727273 0.72727273 0.72727273 0.81818182]
# Random Forest Classifier Accuracy promedio: 0.6727
